# %% [markdown]
# # Install and load packages

# %%
! pip install networkx==3.2

# %%
! pip install seaborn

# %%
import numpy as np

# %matplotlib inline
import matplotlib as mpl

import matplotlib.pyplot as plt
import numpy as np
from collections import Counter
import scipy
import networkx as nx

import seaborn as sns
import pandas as pd

# %config InlineBackend.figure_format = 'svg'
plt.rcParams.update({'font.size': 10, 'font.style': 'normal', 'font.family':'serif'})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 10
#       8 from collections import Counter
#       9 import scipy
# ---> 10 import networkx as nx
#      12 import seaborn as sns
#      13 import pandas as pd
#
# ModuleNotFoundError: No module named 'networkx'

# %% [raw]
# LOAD DATASET

# %%
seriea = pd.read_csv('serie-a(1).csv')
bundesliga = pd.read_csv('1-bundesliga.csv')
eredivise = pd.read_csv('eredivisie.csv')
liganos = pd.read_csv('liga-nos.csv')
ligue1 = pd.read_csv('ligue-1.csv')
premier = pd.read_csv('premier-league.csv')
premier_liga = pd.read_csv('premier-liga.csv')
primera_division = pd.read_csv('primera-division(1).csv')
championship = pd.read_csv('championship.csv')

# %%
seriea
# Out:
#            club_name          player_name   age            position  \
# 0      AC Fiorentina        Brian Laudrup  23.0        Right Winger
# 1      AC Fiorentina     Stefan Effenberg  23.0    Central Midfield
# 2      AC Fiorentina  Daniele Carnasciali  25.0          Right-Back
# 3      AC Fiorentina        Diego Latorre  22.0      Second Striker
# 4      AC Fiorentina      Andrea Vascotto  20.0            midfield
# ...              ...                  ...   ...                 ...
# 28428       AC Monza       Andrea Carboni  21.0         Centre-Back
# 28429       AC Monza   Gabriele Ferrarini  22.0          Right-Back
# 28430       AC Monza        Nicola Rigoni  32.0  Defensive Midfield
# 28431       AC Monza   Matteo Scozzarella  34.0  Defensive Midfield
# 28432       AC Monza      Gabriel Paletta  37.0         Centre-Back
#
#       club_involved_name            fee transfer_movement transfer_period  \
# 0          Bayern Munich         €5.00m                in          Summer
# 1          Bayern Munich         €3.75m                in          Summer
# 2                Brescia              ?                in          Summer
# 3           Boca Juniors              ?                in          Summer
# 4            Barletta CS              ?                in          Summer
# ...                  ...            ...               ...             ...
# 28428            Venezia  loan transfer               out          Winter
# 28429             Modena  loan transfer               out          Winter
# 28430       Without Club              -               out          Winter
# 28431       Without Club              -               out          Winter
# 28432            Retired              -               out          Winter
#
#        fee_cleaned league_name  year     season country
# 0             5.00     Serie A  1992  1992/1993   Italy
# 1             3.75     Serie A  1992  1992/1993   Italy
# 2              NaN     Serie A  1992  1992/1993   Italy
# 3              NaN     Serie A  1992  1992/1993   Italy
# 4              NaN     Serie A  1992  1992/1993   Italy
# ...            ...         ...   ...        ...     ...
# 28428          NaN     Serie A  2022  2022/2023   Italy
# 28429          NaN     Serie A  2022  2022/2023   Italy
# 28430          NaN     Serie A  2022  2022/2023   Italy
# 28431          NaN     Serie A  2022  2022/2023   Italy
# 28432          NaN     Serie A  2022  2022/2023   Italy
#
# [28433 rows x 13 columns]
